# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import yfinance as yf

# %% [markdown]
# Import the data and dataset

# %%
# Find the data of meta's stock price from 1/1/2018 to now
start = datetime.date(2018,1,1)
end = datetime.date.today()
ticker_1 = 'META'
META = yf.download(ticker_1, start, end)
META
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-01-02  177.679993  181.580002  177.550003  181.419998  181.419998
# 2018-01-03  181.880005  184.779999  181.330002  184.669998  184.669998
# 2018-01-04  184.899994  186.210007  184.100006  184.330002  184.330002
# 2018-01-05  185.589996  186.899994  184.929993  186.850006  186.850006
# 2018-01-08  187.199997  188.899994  186.330002  188.279999  188.279999
# ...                ...         ...         ...         ...         ...
# 2023-11-13  326.200012  332.329987  325.700012  329.190002  329.190002
# 2023-11-14  334.540009  338.100006  333.329987  336.309998  336.309998
# 2023-11-15  337.929993  338.399994  330.019989  332.709991  332.709991
# 2023-11-16  329.369995  334.579987  326.380005  334.190002  334.190002
# 2023-11-17  330.260010  335.500000  329.350006  335.040009  335.040009
#
#               Volume
# Date
# ...

# %% [markdown]
# Draw the diagram from the 2018 to now

# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import yfinance as yf

start = datetime.date(2018,1,1)
end = datetime.date.today()
ticker_1 = 'META'
META = yf.download(ticker_1, start, end)

META.drop(columns=["Adj Close"], inplace=True)
META['Open'].plot(label = 'META Open price', figsize = (15,7) )
META['High'].plot(label = 'META High price')
META['Low'].plot(label = 'META Low price')
META['Close'].plot(label = 'META Close price')
plt.title('META Stock Price')
plt.ylabel('Stock Price')
plt.legend()


plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
# *** Please explain the meaning of this ***
META['Open'].plot(label = 'META Open price', figsize = (15,7) )
META['High'].plot(label = 'META High price')
META['Low'].plot(label = 'META Low price')
META['Close'].plot(label = 'META Close price')
plt.title('META Stock Price')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %% [markdown]
# The trade volume of stock is shown following

# %%
META['Volume'].plot(label = 'META Volume ', figsize = (15,7))
plt.title('Volume Traded by META')
plt.legend()
plt.show()

# %% [markdown]
# QQQ:A U.S. index traded fund (an index traded fund designed to generally match the price and return performance of the NASDAQ 100 index), which can be shown as a proof of whole business situation

# %%
# find the consistency for QQQ and Meta
ticker_2 = 'QQQ'
QQQ = yf.download(ticker_2, start, end)
QQQ.drop(columns=["Adj Close"], inplace=True)
QQQ
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close    Volume
# Date
# 2018-01-02  156.559998  158.529999  156.169998  158.490005  32573300
# 2018-01-03  158.639999  160.169998  158.610001  160.029999  29383600
# 2018-01-04  160.580002  160.789993  160.080002  160.309998  24776100
# 2018-01-05  161.070007  162.029999  160.770004  161.919998  26992300
# 2018-01-08  161.919998  162.630005  161.860001  162.550003  23159100
# ...                ...         ...         ...         ...       ...
# 2023-11-13  376.790009  378.279999  375.239990  377.209991  40733500
# 2023-11-14  383.709991  386.260010  383.179993  385.329987  67792600
# 2023-11-15  387.250000  387.750000  384.239990  385.619995  54141400
# 2023-11-16  384.839996  386.190002  383.559998  385.950012  45343500
# 2023-11-17  385.209991  387.070007  384.290009  386.040009  46571900
#
# [1481 rows x 5 columns]

# %%
QQQ['Open'].plot(label = 'QQQ Open price', figsize = (15,7) )
QQQ['High'].plot(label = 'QQQ High price')
QQQ['Low'].plot(label = 'QQQ Low price')
QQQ['Close'].plot(label = 'QQQ Close price')
plt.title('QQQ Stock Price')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
QQQ['Volume'].plot(label = 'QQQ Volume ', figsize = (15,7))
plt.title('Volume Traded by QQQ')
plt.legend()
plt.show()

# %%
ticker_3 = 'SPY'
SPY = yf.download(ticker_3, start, end)
SPY.drop(columns=["Adj Close"], inplace=True)
SPY
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close    Volume
# Date
# 2018-01-02  267.839996  268.809998  267.399994  268.769989  86655700
# 2018-01-03  268.959991  270.640015  268.959991  270.470001  90070400
# 2018-01-04  271.200012  272.160004  270.540009  271.609985  80636400
# 2018-01-05  272.510010  273.559998  271.950012  273.420013  83524000
# 2018-01-08  273.309998  274.100006  272.980011  273.920013  57319200
# ...                ...         ...         ...         ...       ...
# 2023-11-13  439.230011  441.329987  438.420013  440.190002  52236100
# 2023-11-14  446.320007  450.059998  446.089996  448.730011  97176900
# 2023-11-15  450.109985  451.380005  448.799988  449.679993  77327600
# 2023-11-16  449.220001  450.559998  448.119995  450.230011  66665800
# 2023-11-17  450.239990  451.420013  449.290009  450.790009  83133200
#
# [1481 rows x 5 columns]

# %%
SPY['Open'].plot(label = 'SPY Open price', figsize = (15,7) )
SPY['High'].plot(label = 'SPY High price')
SPY['Low'].plot(label = 'SPY Low price')
SPY['Close'].plot(label = 'SPY Close price')
plt.title('SPY Stock Price')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
SPY['Volume'].plot(label = 'SPY Volume ', figsize = (15,7))
plt.title('Volume Traded by SPY')
plt.legend()
plt.show()

# %%
META['Open'].plot(label = 'META', figsize = (15,7))
QQQ['Open'].plot(label = 'QQQ')
SPY['Open'].plot(label = 'SPY')
plt.ylabel('Stock Price')
plt.title('Stock Price of META, QQQ, and SPY')
plt.legend()

# %%
META['Volume'].plot(label = 'META', figsize = (15,7))
QQQ['Volume'].plot(label = 'QQQ')
SPY['Volume'].plot(label = 'SPY')
plt.title('Volume Traded by META, QQQ, and SPY')
plt.legend()

# %%
META['Totoal Traded'] = META['Open'] * META['Volume']
QQQ['Totoal Traded'] = QQQ['Open'] * QQQ['Volume']
SPY['Totoal Traded'] = SPY['Open'] * SPY['Volume']
META.head()
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 2018-01-02  177.679993  181.580002  177.550003  181.419998  18151900
# 2018-01-03  181.880005  184.779999  181.330002  184.669998  16886600
# 2018-01-04  184.899994  186.210007  184.100006  184.330002  13880900
# 2018-01-05  185.589996  186.899994  184.929993  186.850006  13574500
# 2018-01-08  187.199997  188.899994  186.330002  188.279999  17994700
#
#             Totoal Traded
# Date
# 2018-01-02   3.225229e+09
# 2018-01-03   3.071335e+09
# 2018-01-04   2.566578e+09
# 2018-01-05   2.519291e+09
# 2018-01-08   3.368608e+09

# %%
META['Totoal Traded'].plot(label = 'META', figsize = (15, 7))
QQQ['Totoal Traded'].plot(label = 'QQQ')
SPY['Totoal Traded'].plot(label = 'SPY')
plt.legend()
plt.ylabel('Total Traded')
# Out:
# Text(0, 0.5, 'Total Traded')

# %%
META.iloc[[META['Volume'].argmax()]]
# Out:
#                  Open   High        Low      Close     Volume  Totoal Traded
# Date
# 2022-10-27  97.980003  102.5  96.379997  97.940002  232316600   2.276238e+10

# %%
META.iloc[[META['Totoal Traded'].argmax()]]
# Out:
#                   Open   High     Low       Close     Volume  Totoal Traded
# Date
# 2022-02-03  244.649994  248.0  235.75  237.759995  188119900   4.602353e+10

# %%
META.iloc[[META['Totoal Traded'].argmax()]]
# Out:
#                   Open   High     Low       Close     Volume  Totoal Traded
# Date
# 2022-02-03  244.649994  248.0  235.75  237.759995  188119900   4.602353e+10

# %%
META['Open'].plot(label = 'No Moving Average', figsize = (15, 7))
META['MA22'] = META['Open'].rolling(22).mean()
META['MA22'].plot(label = 'MA22 days')
plt.legend()

# %%
from pandas.plotting import scatter_matrix
car_comp = pd.concat([META['Open'], QQQ['Open'], SPY['Open']], axis=1)
car_comp.columns = ['META Open', 'QQQ Open', 'SPY Open']

# %%
scatter_matrix(car_comp, figsize=(15, 7), hist_kwds={'bins': 100})
# Out:
# array([[<Axes: xlabel='META Open', ylabel='META Open'>,
#         <Axes: xlabel='QQQ Open', ylabel='META Open'>,
#         <Axes: xlabel='SPY Open', ylabel='META Open'>],
#        [<Axes: xlabel='META Open', ylabel='QQQ Open'>,
#         <Axes: xlabel='QQQ Open', ylabel='QQQ Open'>,
#         <Axes: xlabel='SPY Open', ylabel='QQQ Open'>],
#        [<Axes: xlabel='META Open', ylabel='SPY Open'>,
#         <Axes: xlabel='QQQ Open', ylabel='SPY Open'>,
#         <Axes: xlabel='SPY Open', ylabel='SPY Open'>]], dtype=object)

# %%
META['Returns'] = (META['Close']/META['Close'].shift(1))-1
QQQ['Returns'] = (QQQ['Close']/QQQ['Close'].shift(1))-1
SPY['Returns'] = (SPY['Close']/SPY['Close'].shift(1))-1

# %%
META.head()
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 2018-01-02  177.679993  181.580002  177.550003  181.419998  18151900
# 2018-01-03  181.880005  184.779999  181.330002  184.669998  16886600
# 2018-01-04  184.899994  186.210007  184.100006  184.330002  13880900
# 2018-01-05  185.589996  186.899994  184.929993  186.850006  13574500
# 2018-01-08  187.199997  188.899994  186.330002  188.279999  17994700
#
#             Totoal Traded  MA22   Returns
# Date
# 2018-01-02   3.225229e+09   NaN       NaN
# 2018-01-03   3.071335e+09   NaN  0.017914
# 2018-01-04   2.566578e+09   NaN -0.001841
# 2018-01-05   2.519291e+09   NaN  0.013671
# 2018-01-08   3.368608e+09   NaN  0.007653

# %%
QQQ.head()
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 2018-01-02  156.559998  158.529999  156.169998  158.490005  32573300
# 2018-01-03  158.639999  160.169998  158.610001  160.029999  29383600
# 2018-01-04  160.580002  160.789993  160.080002  160.309998  24776100
# 2018-01-05  161.070007  162.029999  160.770004  161.919998  26992300
# 2018-01-08  161.919998  162.630005  161.860001  162.550003  23159100
#
#             Totoal Traded   Returns
# Date
# 2018-01-02   5.099676e+09       NaN
# 2018-01-03   4.661414e+09  0.009717
# 2018-01-04   3.978546e+09  0.001750
# 2018-01-05   4.347650e+09  0.010043
# 2018-01-08   3.749921e+09  0.003891

# %%
SPY.head()
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 2018-01-02  267.839996  268.809998  267.399994  268.769989  86655700
# 2018-01-03  268.959991  270.640015  268.959991  270.470001  90070400
# 2018-01-04  271.200012  272.160004  270.540009  271.609985  80636400
# 2018-01-05  272.510010  273.559998  271.950012  273.420013  83524000
# 2018-01-08  273.309998  274.100006  272.980011  273.920013  57319200
#
#             Totoal Traded   Returns
# Date
# 2018-01-02   2.320986e+10       NaN
# 2018-01-03   2.422533e+10  0.006325
# 2018-01-04   2.186859e+10  0.004215
# 2018-01-05   2.276113e+10  0.006664
# 2018-01-08   1.566591e+10  0.001829

# %%
META['Returns'].hist(bins = 100, label = 'META', alpha = 0.5, figsize = (15, 7))
QQQ['Returns'].hist(bins = 100, label = 'QQQ', alpha = 0.5)
SPY['Returns'].hist(bins = 100, label = 'SPY', alpha = 0.5)
plt.legend()

# %%
META['Cumulative Return'] = (1+META['Returns']).cumprod()
QQQ['Cumulative Return'] = (1+QQQ['Returns']).cumprod()
SPY['Cumulative Return'] = (1+SPY['Returns']).cumprod()

# %%
META['Cumulative Return'].plot(label='META', figsize=(15, 7))
QQQ['Cumulative Return'].plot(label='QQQ')
SPY['Cumulative Return'].plot(label='SPY')
plt.title('Cumulative Return vs Time')
plt.legend()

# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import yfinance as yf

start = datetime.date(2018,1,1)
end = datetime.date.today()
ticker_1 = 'META'
META = yf.download(ticker_1, start, end)

META.drop(columns=["Adj Close"], inplace=True)
META['Open'].hist(bins = 100, label = 'META', alpha = 0.5, figsize = (15, 7))
plt.title('META Stock Price')
plt.ylabel('Stock Price')
plt.legend()


plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
data = pd.read_excel('WHR2023.xls')

data['Life Ladder'].hist(bins = 100, label = 'Life Ladder', alpha = 0.5, figsize = (15, 7))
plt.title('Life Ladder')
plt.ylabel('Value')
plt.legend()


plt.show()

# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import yfinance as yf

data = pd.read_excel('WHR2023.xls')
df1 = data.groupby((['year'])).mean()
show = df1.tail(5)
show["Log GDP per capita"].plot(label = 'Log GDP per capita', figsize = (15,7))
plt.title('Log GDP per capita - Global')
plt.ylabel('Value')
plt.legend()


plt.show()
# Out:
# <ipython-input-31-a18c90c93c85>:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df1 = data.groupby((['year'])).mean()

# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import yfinance as yf

data = pd.read_excel('WHR2023.xls')
df1 = data.groupby((['year'])).mean()
show = df1.tail(5)
show["Social support"].plot(label = 'Social support', figsize = (15,7))
plt.title('Social support - Global')
plt.ylabel('Value')
plt.legend()


plt.show()
# Out:
# <ipython-input-32-8249ed473aa7>:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df1 = data.groupby((['year'])).mean()

# %%
import pandas as pd
import matplotlib.pyplot as plt

file_path = "Suicide rate.csv"
suicide_data = pd.read_csv(file_path)

# Filter data for the United States and the desired period
usa_data = suicide_data[(suicide_data["Location"] == "United States of America")& (suicide_data["Dim1"] == "Both sexes")]

# %%
usa_data
# Out:
#       IndicatorCode                                     Indicator ValueType  \
# 141      SDGSUICIDE  Crude suicide rates (per 100 000 population)      text
# 684      SDGSUICIDE  Crude suicide rates (per 100 000 population)      text
# 1239     SDGSUICIDE  Crude suicide rates (per 100 000 population)      text
# 1776     SDGSUICIDE  Crude suicide rates (per 100 000 population)      text
# 2316     SDGSUICIDE  Crude suicide rates (per 100 000 population)      text
# 2860     SDGSUICIDE  Crude suicide rates (per 100 000 population)      text
# 3403     SDGSUICIDE  Crude suicide rates (per 100 000 population)      text
# 3958     SDGSUICIDE  Crude suicide rates (per 100 000 population)      text
# 4505     SDGSUICIDE  Crude suicide rates (per 100 000 population)      text
# 5066     SDGSUICIDE  Crude suicide rates (per 100 000 population)      text
# 5599     SDGSUICIDE  Crude suicide rates (per 100 000 population)      text
# ...

# %%
suicide_df = pd.DataFrame({'Year': usa_data["Period"], 'Suicide Rate': usa_data["FactValueNumeric"]})
suicide_df
# Out:
#        Year  Suicide Rate
# 141    2019         16.14
# 684    2018         15.68
# 1239   2017         15.89
# 1776   2016         15.15
# 2316   2015         14.40
# 2860   2014         13.97
# 3403   2013         13.55
# 3958   2012         13.51
# 4505   2011         13.39
# 5066   2010         13.10
# 5599   2009         12.76
# 6146   2008         12.69
# 6692   2007         12.41
# 7227   2006         12.13
# 7761   2005         11.86
# 8310   2004         11.91
# 8863   2003         11.70
# 9406   2002         11.77
# 9955   2001         11.39
# 10491  2000         11.03

# %%
plt.figure(figsize=(15, 6))
plt.plot(suicide_df["Year"],suicide_df["Suicide Rate"], marker='o', linestyle='-')
plt.title('Suicide Rates in the United States (2000-2019)')
plt.xlabel('Year')
plt.ylabel('Suicide Rate (per 100,000 population)')
plt.grid(True)
plt.xlim(2012, 2019)
plt.show()

# %%
start2 = datetime.date(2000,1,1)
end2 = datetime.date.today()
ticker_1 = 'META'
META2 = yf.download(ticker_1, start, end)
META2
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-01-02  177.679993  181.580002  177.550003  181.419998  181.419998
# 2018-01-03  181.880005  184.779999  181.330002  184.669998  184.669998
# 2018-01-04  184.899994  186.210007  184.100006  184.330002  184.330002
# 2018-01-05  185.589996  186.899994  184.929993  186.850006  186.850006
# 2018-01-08  187.199997  188.899994  186.330002  188.279999  188.279999
# ...                ...         ...         ...         ...         ...
# 2023-11-13  326.200012  332.329987  325.700012  329.190002  329.190002
# 2023-11-14  334.540009  338.100006  333.329987  336.309998  336.309998
# 2023-11-15  337.929993  338.399994  330.019989  332.709991  332.709991
# 2023-11-16  329.369995  334.579987  326.380005  334.190002  334.190002
# 2023-11-17  330.260010  335.500000  329.350006  335.040009  335.040009
#
#               Volume
# Date
# ...

# %%
file_path2 = "META.csv"
Old_Stock_Data = pd.read_csv(file_path2)

plt.figure(figsize=(80, 10))

plt.plot(Old_Stock_Data['Date'], Old_Stock_Data['Open'], label='Open', marker='o', linestyle='-', color='blue')
plt.plot(Old_Stock_Data['Date'], Old_Stock_Data['High'], label='High', marker='o', linestyle='-', color='orange')
plt.plot(Old_Stock_Data['Date'], Old_Stock_Data['Low'], label='Low', marker='o', linestyle='-', color='red')

plt.plot(Old_Stock_Data['Date'], Old_Stock_Data['Close'], label='Close', marker='o', linestyle='-', color='green')
plt.title('META Stock Price')
plt.ylabel('Stock Price')
plt.legend()
